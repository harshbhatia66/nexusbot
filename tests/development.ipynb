# %%
import os
import torch
from speechbrain.pretrained import SpeakerRecognition
from speechbrain.pretrained import EncoderClassifier
from speechbrain.pretrained import Pretrained
import sqlite3
import tempfile
import re

# Load the speaker recognition model
sr_model = SpeakerRecognition.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")

# Load the encoder classifier model
ec_model = EncoderClassifier.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")

p_model = Pretrained.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")

# Extract the embeddings of the reference audio file
reference_file = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/data/training/standard.wav"
waveform_x = p_model.load_audio(path=reference_file)
batch_x = waveform_x.unsqueeze(0)
emb_ref = ec_model.encode_batch(batch_x, normalize=True)

similarity = torch.nn.CosineSimilarity(dim=-1, eps=1e-6)

folder_path = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data"
metadata_db_path = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/metadata.db"

# %%
temp_dir = tempfile.gettempdir()

count_fail = 0
from natsort import natsorted
# Connect to the SQLite database
conn = sqlite3.connect(metadata_db_path)
c = conn.cursor()

# Create the table for storing metadata
c.execute('''CREATE TABLE IF NOT EXISTS speaker_files
             (id INTEGER PRIMARY KEY AUTOINCREMENT, file_path TEXT, is_speaker INTEGER)''')

# Loop through all the files in the folder and check for similarity with reference audio file
for file in natsorted(os.listdir(folder_path), key=lambda x: (x.split("_")[0], int(x.split("_")[1].split(".")[0][7:]))):
    if file.endswith('.wav'):
        waveform_y = p_model.load_audio(path=os.path.join(folder_path, file), savedir=temp_dir)
        batch_y = waveform_y.unsqueeze(0)
        emb_y = ec_model.encode_batch(batch_y, normalize=True)
        score = similarity(emb_y, emb_ref)
        is_speaker = 1 if score > 0.25 else 0
        if is_speaker == 0:
            count_fail += 1
        print(f"File: {file} Score: {score} Passes Verification: {is_speaker}")
        
        # Insert the metadata into the database
        c.execute("INSERT INTO speaker_files (file_path, is_speaker) VALUES (?, ?)", (os.path.join(folder_path, file), is_speaker))
        
        os.remove(os.path.join(temp_dir, file))

# Commit the changes to the database and close the connection
conn.commit()
conn.close()
# Out:
# File: video1_segment1.wav Score: tensor([[0.7505]]) Passes Verification: 1
# File: video1_segment2.wav Score: tensor([[0.8099]]) Passes Verification: 1
# File: video1_segment3.wav Score: tensor([[0.7106]]) Passes Verification: 1
# File: video1_segment4.wav Score: tensor([[0.7204]]) Passes Verification: 1
# File: video1_segment5.wav Score: tensor([[0.7986]]) Passes Verification: 1
# File: video1_segment6.wav Score: tensor([[0.7662]]) Passes Verification: 1
# File: video1_segment7.wav Score: tensor([[0.6875]]) Passes Verification: 1
# File: video1_segment8.wav Score: tensor([[0.7853]]) Passes Verification: 1
# File: video1_segment9.wav Score: tensor([[0.8199]]) Passes Verification: 1
# File: video1_segment10.wav Score: tensor([[0.8010]]) Passes Verification: 1
# File: video1_segment11.wav Score: tensor([[0.7689]]) Passes Verification: 1
# File: video1_segment12.wav Score: tensor([[0.7507]]) Passes Verification: 1
# File: video1_segment13.wav Score: tensor([[0.7314]]) Passes Verification: 1
# File: video1_segment14.wav Score: tensor([[0.7510]]) Passes Verification: 1
# File: video1_segment15.wav Score: tensor([[0.6204]]) Passes Verification: 1
# File: video1_segment16.wav Score: tensor([[0.7992]]) Passes Verification: 1
# File: video1_segment17.wav Score: tensor([[0.7503]]) Passes Verification: 1
# File: video1_segment18.wav Score: tensor([[0.7761]]) Passes Verification: 1
# File: video1_segment19.wav Score: tensor([[0.8085]]) Passes Verification: 1
# File: video1_segment20.wav Score: tensor([[0.8004]]) Passes Verification: 1
# File: video1_segment21.wav Score: tensor([[0.7034]]) Passes Verification: 1
# File: video1_segment22.wav Score: tensor([[0.6002]]) Passes Verification: 1
# File: video1_segment23.wav Score: tensor([[0.5587]]) Passes Verification: 1
# File: video1_segment24.wav Score: tensor([[0.7546]]) Passes Verification: 1
# File: video1_segment25.wav Score: tensor([[0.6863]]) Passes Verification: 1
# File: video1_segment26.wav Score: tensor([[0.7319]]) Passes Verification: 1
# File: video1_segment27.wav Score: tensor([[0.6177]]) Passes Verification: 1
# File: video1_segment28.wav Score: tensor([[0.7016]]) Passes Verification: 1
# File: video1_segment29.wav Score: tensor([[0.7981]]) Passes Verification: 1
# File: video1_segment30.wav Score: tensor([[0.7131]]) Passes Verification: 1
# File: video1_segment31.wav Score: tensor([[0.7845]]) Passes Verification: 1
# File: video1_segment32.wav Score: tensor([[0.6778]]) Passes Verification: 1
# File: video1_segment33.wav Score: tensor([[0.6949]]) Passes Verification: 1
# File: video1_segment34.wav Score: tensor([[0.8211]]) Passes Verification: 1
# File: video1_segment35.wav Score: tensor([[0.7511]]) Passes Verification: 1
# File: video1_segment36.wav Score: tensor([[0.7183]]) Passes Verification: 1
# File: video1_segment37.wav Score: tensor([[0.8167]]) Passes Verification: 1
# File: video1_segment38.wav Score: tensor([[0.8343]]) Passes Verification: 1
# File: video1_segment39.wav Score: tensor([[0.8294]]) Passes Verification: 1
# File: video1_segment40.wav Score: tensor([[0.8243]]) Passes Verification: 1
# File: video1_segment41.wav Score: tensor([[0.8127]]) Passes Verification: 1
# File: video1_segment42.wav Score: tensor([[0.7112]]) Passes Verification: 1
# File: video1_segment43.wav Score: tensor([[0.6789]]) Passes Verification: 1
# File: video1_segment44.wav Score: tensor([[0.8041]]) Passes Verification: 1
# File: video1_segment45.wav Score: tensor([[0.8282]]) Passes Verification: 1
# File: video1_segment46.wav Score: tensor([[0.8096]]) Passes Verification: 1
# File: video1_segment47.wav Score: tensor([[0.7125]]) Passes Verification: 1
# File: video1_segment48.wav Score: tensor([[0.8199]]) Passes Verification: 1
# File: video1_segment49.wav Score: tensor([[0.7949]]) Passes Verification: 1
# File: video1_segment50.wav Score: tensor([[0.7353]]) Passes Verification: 1
# File: video1_segment51.wav Score: tensor([[0.6919]]) Passes Verification: 1
# File: video1_segment52.wav Score: tensor([[0.7816]]) Passes Verification: 1
# File: video1_segment53.wav Score: tensor([[0.6895]]) Passes Verification: 1
# File: video1_segment54.wav Score: tensor([[0.7802]]) Passes Verification: 1
# File: video1_segment55.wav Score: tensor([[0.7645]]) Passes Verification: 1
# File: video1_segment56.wav Score: tensor([[0.8568]]) Passes Verification: 1
# File: video1_segment57.wav Score: tensor([[0.8153]]) Passes Verification: 1
# File: video1_segment58.wav Score: tensor([[0.8205]]) Passes Verification: 1
# File: video1_segment59.wav Score: tensor([[0.7562]]) Passes Verification: 1
# File: video1_segment60.wav Score: tensor([[0.7927]]) Passes Verification: 1
# File: video1_segment61.wav Score: tensor([[0.7568]]) Passes Verification: 1
# File: video1_segment62.wav Score: tensor([[0.7487]]) Passes Verification: 1
# File: video1_segment63.wav Score: tensor([[0.8004]]) Passes Verification: 1
# File: video1_segment64.wav Score: tensor([[0.7865]]) Passes Verification: 1
# File: video1_segment65.wav Score: tensor([[0.7288]]) Passes Verification: 1
# File: video1_segment66.wav Score: tensor([[0.8435]]) Passes Verification: 1
# File: video1_segment67.wav Score: tensor([[0.7029]]) Passes Verification: 1
# File: video1_segment68.wav Score: tensor([[0.7841]]) Passes Verification: 1
# File: video1_segment69.wav Score: tensor([[0.7199]]) Passes Verification: 1
# File: video1_segment70.wav Score: tensor([[0.6787]]) Passes Verification: 1
# File: video1_segment71.wav Score: tensor([[0.7420]]) Passes Verification: 1
# File: video1_segment72.wav Score: tensor([[0.8143]]) Passes Verification: 1
# File: video1_segment73.wav Score: tensor([[0.7735]]) Passes Verification: 1
# File: video1_segment74.wav Score: tensor([[0.7427]]) Passes Verification: 1
# File: video1_segment75.wav Score: tensor([[0.8357]]) Passes Verification: 1
# File: video1_segment76.wav Score: tensor([[0.7553]]) Passes Verification: 1
# File: video1_segment77.wav Score: tensor([[0.7734]]) Passes Verification: 1
# File: video1_segment78.wav Score: tensor([[0.6736]]) Passes Verification: 1
# File: video1_segment79.wav Score: tensor([[0.6827]]) Passes Verification: 1
# File: video1_segment80.wav Score: tensor([[0.8015]]) Passes Verification: 1
# File: video1_segment81.wav Score: tensor([[0.7905]]) Passes Verification: 1
# File: video1_segment82.wav Score: tensor([[0.7446]]) Passes Verification: 1
# File: video1_segment83.wav Score: tensor([[0.6878]]) Passes Verification: 1
# File: video1_segment84.wav Score: tensor([[0.7311]]) Passes Verification: 1
# File: video1_segment85.wav Score: tensor([[0.7738]]) Passes Verification: 1
# File: video1_segment86.wav Score: tensor([[0.7832]]) Passes Verification: 1
# File: video1_segment87.wav Score: tensor([[0.7817]]) Passes Verification: 1
# File: video1_segment88.wav Score: tensor([[0.8409]]) Passes Verification: 1
# File: video1_segment89.wav Score: tensor([[0.7385]]) Passes Verification: 1
# File: video1_segment90.wav Score: tensor([[0.7503]]) Passes Verification: 1
# File: video1_segment91.wav Score: tensor([[0.8005]]) Passes Verification: 1
# File: video1_segment92.wav Score: tensor([[0.5120]]) Passes Verification: 1
# File: video1_segment93.wav Score: tensor([[0.7848]]) Passes Verification: 1
# File: video1_segment94.wav Score: tensor([[0.6079]]) Passes Verification: 1
# File: video1_segment95.wav Score: tensor([[0.6360]]) Passes Verification: 1
# File: video1_segment96.wav Score: tensor([[0.8143]]) Passes Verification: 1
# File: video1_segment97.wav Score: tensor([[0.6555]]) Passes Verification: 1
# File: video1_segment98.wav Score: tensor([[0.8215]]) Passes Verification: 1
# File: video1_segment99.wav Score: tensor([[0.6288]]) Passes Verification: 1
# File: video1_segment100.wav Score: tensor([[0.6249]]) Passes Verification: 1
# File: video1_segment101.wav Score: tensor([[0.5675]]) Passes Verification: 1
# File: video1_segment102.wav Score: tensor([[0.8186]]) Passes Verification: 1
# File: video1_segment103.wav Score: tensor([[0.6048]]) Passes Verification: 1
# File: video1_segment104.wav Score: tensor([[0.0787]]) Passes Verification: 0
# File: video2_segment1.wav Score: tensor([[0.7669]]) Passes Verification: 1
# File: video2_segment2.wav Score: tensor([[0.1570]]) Passes Verification: 0
# File: video2_segment3.wav Score: tensor([[0.1415]]) Passes Verification: 0
# File: video2_segment4.wav Score: tensor([[0.4016]]) Passes Verification: 1
# File: video2_segment5.wav Score: tensor([[0.6659]]) Passes Verification: 1
# File: video2_segment6.wav Score: tensor([[0.3495]]) Passes Verification: 1
# File: video2_segment7.wav Score: tensor([[0.6626]]) Passes Verification: 1
# File: video2_segment8.wav Score: tensor([[0.5460]]) Passes Verification: 1
# File: video2_segment9.wav Score: tensor([[0.4832]]) Passes Verification: 1
# File: video2_segment10.wav Score: tensor([[0.5527]]) Passes Verification: 1
# File: video2_segment11.wav Score: tensor([[0.2966]]) Passes Verification: 1
# File: video2_segment12.wav Score: tensor([[0.2337]]) Passes Verification: 0
# File: video2_segment13.wav Score: tensor([[0.0958]]) Passes Verification: 0
# File: video2_segment14.wav Score: tensor([[0.1364]]) Passes Verification: 0
# File: video2_segment15.wav Score: tensor([[0.1926]]) Passes Verification: 0
# File: video2_segment16.wav Score: tensor([[-0.0743]]) Passes Verification: 0
# File: video2_segment17.wav Score: tensor([[-0.1080]]) Passes Verification: 0
# File: video2_segment18.wav Score: tensor([[0.7126]]) Passes Verification: 1
# File: video2_segment19.wav Score: tensor([[0.4456]]) Passes Verification: 1
# File: video2_segment20.wav Score: tensor([[0.2729]]) Passes Verification: 1
# File: video2_segment21.wav Score: tensor([[0.1830]]) Passes Verification: 0
# File: video2_segment22.wav Score: tensor([[0.0776]]) Passes Verification: 0
# File: video2_segment23.wav Score: tensor([[0.1684]]) Passes Verification: 0
# File: video2_segment24.wav Score: tensor([[0.3541]]) Passes Verification: 1
# File: video2_segment25.wav Score: tensor([[0.2012]]) Passes Verification: 0
# File: video2_segment26.wav Score: tensor([[0.0482]]) Passes Verification: 0
# File: video2_segment27.wav Score: tensor([[0.7873]]) Passes Verification: 1
# File: video2_segment28.wav Score: tensor([[0.5931]]) Passes Verification: 1
# File: video2_segment29.wav Score: tensor([[0.7084]]) Passes Verification: 1
# File: video2_segment30.wav Score: tensor([[0.7068]]) Passes Verification: 1
# File: video2_segment31.wav Score: tensor([[0.5066]]) Passes Verification: 1
# File: video2_segment32.wav Score: tensor([[0.4312]]) Passes Verification: 1
# File: video2_segment33.wav Score: tensor([[-0.0376]]) Passes Verification: 0
# File: video2_segment34.wav Score: tensor([[0.0182]]) Passes Verification: 0
# File: video2_segment35.wav Score: tensor([[0.2730]]) Passes Verification: 1
# File: video2_segment36.wav Score: tensor([[0.4114]]) Passes Verification: 1
# File: video2_segment37.wav Score: tensor([[0.6188]]) Passes Verification: 1
# File: video2_segment38.wav Score: tensor([[0.7057]]) Passes Verification: 1
# File: video2_segment39.wav Score: tensor([[0.4837]]) Passes Verification: 1
# File: video2_segment40.wav Score: tensor([[0.0971]]) Passes Verification: 0
# File: video2_segment41.wav Score: tensor([[0.0607]]) Passes Verification: 0
# File: video2_segment42.wav Score: tensor([[0.2613]]) Passes Verification: 1
# File: video2_segment43.wav Score: tensor([[0.1312]]) Passes Verification: 0
# File: video2_segment44.wav Score: tensor([[0.2544]]) Passes Verification: 1
# File: video2_segment45.wav Score: tensor([[0.1359]]) Passes Verification: 0
# File: video2_segment46.wav Score: tensor([[0.4555]]) Passes Verification: 1
# File: video2_segment47.wav Score: tensor([[0.6850]]) Passes Verification: 1
# File: video2_segment48.wav Score: tensor([[0.1278]]) Passes Verification: 0
# File: video2_segment49.wav Score: tensor([[0.1333]]) Passes Verification: 0
# File: video2_segment50.wav Score: tensor([[0.1961]]) Passes Verification: 0
# File: video2_segment51.wav Score: tensor([[0.0718]]) Passes Verification: 0
# File: video2_segment52.wav Score: tensor([[0.2936]]) Passes Verification: 1
# File: video2_segment53.wav Score: tensor([[0.6798]]) Passes Verification: 1
# File: video2_segment54.wav Score: tensor([[0.4251]]) Passes Verification: 1
# File: video2_segment55.wav Score: tensor([[0.7797]]) Passes Verification: 1
# File: video2_segment56.wav Score: tensor([[0.7692]]) Passes Verification: 1
# File: video2_segment57.wav Score: tensor([[0.6500]]) Passes Verification: 1
# File: video2_segment58.wav Score: tensor([[0.6550]]) Passes Verification: 1
# File: video2_segment59.wav Score: tensor([[0.2690]]) Passes Verification: 1
# File: video2_segment60.wav Score: tensor([[0.6705]]) Passes Verification: 1
# File: video2_segment61.wav Score: tensor([[-0.0382]]) Passes Verification: 0
# File: video2_segment62.wav Score: tensor([[-0.0676]]) Passes Verification: 0
# File: video2_segment63.wav Score: tensor([[0.4237]]) Passes Verification: 1
# File: video2_segment64.wav Score: tensor([[0.2371]]) Passes Verification: 0
# File: video2_segment65.wav Score: tensor([[0.4589]]) Passes Verification: 1
# File: video2_segment66.wav Score: tensor([[0.3226]]) Passes Verification: 1
# File: video2_segment67.wav Score: tensor([[0.1642]]) Passes Verification: 0
# File: video2_segment68.wav Score: tensor([[-0.1610]]) Passes Verification: 0
# File: video2_segment69.wav Score: tensor([[0.5871]]) Passes Verification: 1
# File: video2_segment70.wav Score: tensor([[0.4216]]) Passes Verification: 1
# File: video2_segment71.wav Score: tensor([[0.6188]]) Passes Verification: 1
# File: video2_segment72.wav Score: tensor([[0.4038]]) Passes Verification: 1
# File: video2_segment73.wav Score: tensor([[0.1349]]) Passes Verification: 0
# File: video2_segment74.wav Score: tensor([[0.2083]]) Passes Verification: 0
# File: video2_segment75.wav Score: tensor([[0.6002]]) Passes Verification: 1
# File: video2_segment76.wav Score: tensor([[0.1326]]) Passes Verification: 0
# File: video2_segment77.wav Score: tensor([[0.5733]]) Passes Verification: 1
# File: video2_segment78.wav Score: tensor([[0.4377]]) Passes Verification: 1
# File: video2_segment79.wav Score: tensor([[0.5645]]) Passes Verification: 1
# File: video2_segment80.wav Score: tensor([[0.2048]]) Passes Verification: 0
# File: video2_segment81.wav Score: tensor([[0.6542]]) Passes Verification: 1
# File: video2_segment82.wav Score: tensor([[0.6272]]) Passes Verification: 1
# File: video2_segment83.wav Score: tensor([[0.5752]]) Passes Verification: 1
# File: video2_segment84.wav Score: tensor([[0.6538]]) Passes Verification: 1
# File: video2_segment85.wav Score: tensor([[0.2351]]) Passes Verification: 0
# File: video2_segment86.wav Score: tensor([[0.3999]]) Passes Verification: 1
# File: video2_segment87.wav Score: tensor([[-0.0014]]) Passes Verification: 0
# File: video2_segment88.wav Score: tensor([[0.0575]]) Passes Verification: 0
# File: video2_segment89.wav Score: tensor([[0.5764]]) Passes Verification: 1
# File: video2_segment90.wav Score: tensor([[0.1231]]) Passes Verification: 0
# File: video2_segment91.wav Score: tensor([[0.1215]]) Passes Verification: 0
# File: video2_segment92.wav Score: tensor([[0.2584]]) Passes Verification: 1
# File: video2_segment93.wav Score: tensor([[0.1191]]) Passes Verification: 0
# File: video2_segment94.wav Score: tensor([[0.1525]]) Passes Verification: 0
# File: video2_segment95.wav Score: tensor([[0.1187]]) Passes Verification: 0
# File: video2_segment96.wav Score: tensor([[0.2387]]) Passes Verification: 0
# File: video2_segment97.wav Score: tensor([[0.5404]]) Passes Verification: 1
# File: video2_segment98.wav Score: tensor([[-0.0300]]) Passes Verification: 0
# File: video2_segment99.wav Score: tensor([[0.4367]]) Passes Verification: 1
# File: video2_segment100.wav Score: tensor([[-0.0590]]) Passes Verification: 0
# File: video2_segment101.wav Score: tensor([[0.7856]]) Passes Verification: 1
# File: video2_segment102.wav Score: tensor([[0.6600]]) Passes Verification: 1
# File: video2_segment103.wav Score: tensor([[0.4995]]) Passes Verification: 1
# File: video2_segment104.wav Score: tensor([[0.7570]]) Passes Verification: 1
# File: video2_segment105.wav Score: tensor([[0.5428]]) Passes Verification: 1
# File: video2_segment106.wav Score: tensor([[0.5611]]) Passes Verification: 1
# File: video2_segment107.wav Score: tensor([[0.4517]]) Passes Verification: 1
# File: video2_segment108.wav Score: tensor([[-0.0627]]) Passes Verification: 0
# File: video2_segment109.wav Score: tensor([[0.0128]]) Passes Verification: 0
# File: video2_segment110.wav Score: tensor([[-0.0648]]) Passes Verification: 0
# File: video2_segment111.wav Score: tensor([[0.2485]]) Passes Verification: 0
# File: video2_segment112.wav Score: tensor([[0.6505]]) Passes Verification: 1
# File: video2_segment113.wav Score: tensor([[-0.0256]]) Passes Verification: 0
# File: video2_segment114.wav Score: tensor([[-0.0836]]) Passes Verification: 0
# File: video2_segment115.wav Score: tensor([[-0.0339]]) Passes Verification: 0
# File: video2_segment116.wav Score: tensor([[0.5932]]) Passes Verification: 1
# File: video2_segment117.wav Score: tensor([[0.4381]]) Passes Verification: 1
# File: video2_segment118.wav Score: tensor([[0.6207]]) Passes Verification: 1
# File: video2_segment119.wav Score: tensor([[0.1100]]) Passes Verification: 0
# File: video2_segment120.wav Score: tensor([[0.4512]]) Passes Verification: 1
# File: video2_segment121.wav Score: tensor([[0.4005]]) Passes Verification: 1
# File: video2_segment122.wav Score: tensor([[0.4795]]) Passes Verification: 1
# File: video2_segment123.wav Score: tensor([[-0.1003]]) Passes Verification: 0
# File: video2_segment124.wav Score: tensor([[0.6810]]) Passes Verification: 1
# File: video2_segment125.wav Score: tensor([[0.7101]]) Passes Verification: 1
# File: video2_segment126.wav Score: tensor([[-0.0208]]) Passes Verification: 0
# File: video2_segment127.wav Score: tensor([[0.6212]]) Passes Verification: 1
# File: video2_segment128.wav Score: tensor([[0.6006]]) Passes Verification: 1
# File: video2_segment129.wav Score: tensor([[0.7338]]) Passes Verification: 1
# File: video2_segment130.wav Score: tensor([[-0.0551]]) Passes Verification: 0
# File: video2_segment131.wav Score: tensor([[-0.0488]]) Passes Verification: 0
# File: video2_segment132.wav Score: tensor([[0.6374]]) Passes Verification: 1
# File: video2_segment133.wav Score: tensor([[0.5124]]) Passes Verification: 1
# File: video2_segment134.wav Score: tensor([[0.4772]]) Passes Verification: 1
# File: video2_segment135.wav Score: tensor([[0.6788]]) Passes Verification: 1
# File: video2_segment136.wav Score: tensor([[0.6375]]) Passes Verification: 1
# File: video2_segment137.wav Score: tensor([[0.6580]]) Passes Verification: 1
# File: video2_segment138.wav Score: tensor([[-0.0494]]) Passes Verification: 0
# File: video2_segment139.wav Score: tensor([[-0.0281]]) Passes Verification: 0
# File: video2_segment140.wav Score: tensor([[0.5692]]) Passes Verification: 1
# File: video2_segment141.wav Score: tensor([[0.2998]]) Passes Verification: 1
# File: video2_segment142.wav Score: tensor([[0.5552]]) Passes Verification: 1
# File: video2_segment143.wav Score: tensor([[0.6772]]) Passes Verification: 1
# File: video2_segment144.wav Score: tensor([[0.0225]]) Passes Verification: 0
# File: video2_segment145.wav Score: tensor([[0.5204]]) Passes Verification: 1
# File: video2_segment146.wav Score: tensor([[-0.0590]]) Passes Verification: 0
# File: video2_segment147.wav Score: tensor([[0.1736]]) Passes Verification: 0
# File: video2_segment148.wav Score: tensor([[0.0103]]) Passes Verification: 0
# File: video2_segment149.wav Score: tensor([[0.3825]]) Passes Verification: 1
# File: video2_segment150.wav Score: tensor([[0.4949]]) Passes Verification: 1
# File: video2_segment151.wav Score: tensor([[0.0906]]) Passes Verification: 0
# File: video2_segment152.wav Score: tensor([[0.2929]]) Passes Verification: 1
# File: video2_segment153.wav Score: tensor([[0.0659]]) Passes Verification: 0
# File: video2_segment154.wav Score: tensor([[0.6925]]) Passes Verification: 1
# File: video2_segment155.wav Score: tensor([[0.7125]]) Passes Verification: 1
# File: video2_segment156.wav Score: tensor([[-0.0134]]) Passes Verification: 0
# File: video2_segment157.wav Score: tensor([[0.2357]]) Passes Verification: 0
# File: video2_segment158.wav Score: tensor([[-0.0457]]) Passes Verification: 0
# File: video2_segment159.wav Score: tensor([[0.5632]]) Passes Verification: 1
# File: video2_segment160.wav Score: tensor([[-0.0215]]) Passes Verification: 0
# File: video2_segment161.wav Score: tensor([[-0.0305]]) Passes Verification: 0
# File: video2_segment162.wav Score: tensor([[0.8128]]) Passes Verification: 1
# File: video2_segment163.wav Score: tensor([[0.7341]]) Passes Verification: 1
# File: video2_segment164.wav Score: tensor([[0.7579]]) Passes Verification: 1
# File: video2_segment165.wav Score: tensor([[0.6287]]) Passes Verification: 1

# %%
print(file)
# Out:
# video2_segment165.txt

# %%
import sqlite3

metadata_db_path = "metadata.db"

# Connect to the SQLite database
conn = sqlite3.connect(metadata_db_path)
c = conn.cursor()

# Query the database and print the results
for row in c.execute("SELECT * FROM speaker_files"):
    print(row)

# Close the connection
conn.close()
# Out:
# (1, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment1.wav', 1)
# (2, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment2.wav', 1)
# (3, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment3.wav', 1)
# (4, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment4.wav', 1)
# (5, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment5.wav', 1)
# (6, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment6.wav', 1)
# (7, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment7.wav', 1)
# (8, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment8.wav', 1)
# (9, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment9.wav', 1)
# (10, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment10.wav', 1)
# (11, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment11.wav', 1)
# (12, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment12.wav', 1)
# (13, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment13.wav', 1)
# (14, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment14.wav', 1)
# (15, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment15.wav', 1)
# (16, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment16.wav', 1)
# (17, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment17.wav', 1)
# (18, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment18.wav', 1)
# (19, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment19.wav', 1)
# (20, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment20.wav', 1)
# (21, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment21.wav', 1)
# (22, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment22.wav', 1)
# (23, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment23.wav', 1)
# (24, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment24.wav', 1)
# (25, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment25.wav', 1)
# (26, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment26.wav', 1)
# (27, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment27.wav', 1)
# (28, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment28.wav', 1)
# (29, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment29.wav', 1)
# (30, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment30.wav', 1)
# (31, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment31.wav', 1)
# (32, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment32.wav', 1)
# (33, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment33.wav', 1)
# (34, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment34.wav', 1)
# (35, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment35.wav', 1)
# (36, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment36.wav', 1)
# (37, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment37.wav', 1)
# (38, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment38.wav', 1)
# (39, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment39.wav', 1)
# (40, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment40.wav', 1)
# (41, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment41.wav', 1)
# (42, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment42.wav', 1)
# (43, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment43.wav', 1)
# (44, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment44.wav', 1)
# (45, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment45.wav', 1)
# (46, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment46.wav', 1)
# (47, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment47.wav', 1)
# (48, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment48.wav', 1)
# (49, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment49.wav', 1)
# (50, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment50.wav', 1)
# (51, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment51.wav', 1)
# (52, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment52.wav', 1)
# (53, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment53.wav', 1)
# (54, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment54.wav', 1)
# (55, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment55.wav', 1)
# (56, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment56.wav', 1)
# (57, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment57.wav', 1)
# (58, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment58.wav', 1)
# (59, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment59.wav', 1)
# (60, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment60.wav', 1)
# (61, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment61.wav', 1)
# (62, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment62.wav', 1)
# (63, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment63.wav', 1)
# (64, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment64.wav', 1)
# (65, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment65.wav', 1)
# (66, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment66.wav', 1)
# (67, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment67.wav', 1)
# (68, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment68.wav', 1)
# (69, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment69.wav', 1)
# (70, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment70.wav', 1)
# (71, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment71.wav', 1)
# (72, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment72.wav', 1)
# (73, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_seg
'/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment165.wav', 1)

# %%
import sqlite3

def create_transcripts(metadata_db_file, transcripts_dir):
    # Connect to the metadata database file
    conn = sqlite3.connect(metadata_db_file)
    c = conn.cursor()
    
    # Select all the rows from the speaker_files table
    c.execute("SELECT * FROM speaker_files")
    rows = c.fetchall()
    
    # Loop through each row in the table
    current_speaker = None
    speaker_prefix = ""
    speaker_text = ""
    current_video = None
    for row in rows:
        # Get the file path and the is_speaker value
        file_path = row[1]
        is_speaker = row[2]
        
        # Split the file path into parts
        parts = file_path.split("/")
        
        # Get the file name
        file_name = parts[-1]
        
        # Split the file name into parts
        parts = file_name.split(".")
        
        # Get the base file name (without the extension)
        base_file_name = parts[0]
        
        # Split the base file name into parts
        parts = base_file_name.split("_")
        
        # Get the video number and segment number
        video_number = int(parts[0].replace("video", ""))
        segment_number = int(parts[1].replace("segment", ""))
        
        # Create the text file path
        text_file_path = "/".join(file_path.split("/")[:-1]) + "/" + base_file_name + ".txt"
        
        # Read the text file
        with open(text_file_path, "r") as f:
            text = f.read()
        
        # If the current speaker has changed, write the previous speaker's text to the transcript file
        if current_speaker is not None and current_speaker != is_speaker:
            transcript_file_path = f"{transcripts_dir}/video{current_video}_dialogue_transcript.txt"
            with open(transcript_file_path, "a") as f:
                f.write(speaker_prefix + speaker_text + "\n")
            
            # Reset the speaker text
            speaker_text = ""
        
        # Add the speaker and text to the transcript
        if is_speaker:
            speaker_prefix = "[Speaker]: "
        else:
            speaker_prefix = "[Context]: "
        
        # Update the current speaker and speaker text
        current_speaker = is_speaker
        speaker_text
        speaker_text += text + " "
        current_video = video_number
    
    # Write the last speaker's text to the transcript file
    transcript_file_path = f"{transcripts_dir}/video{current_video}_dialogue_transcript.txt"
    with open(transcript_file_path, "a") as f:
        f.write(speaker_prefix + speaker_text + "\n")
    
    # Close the connection to the database
    conn.close()

# Example usage
metadata_db_file = "metadata.db"
transcripts_dir = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/data/dialogue_transcripts"
create_transcripts(metadata_db_file, transcripts_dir)

# %%
import os
import torch
from speechbrain.pretrained import SpeakerRecognition
from speechbrain.pretrained import EncoderClassifier
from speechbrain.pretrained import Pretrained
import sqlite3
import tempfile
import re
from natsort import natsorted

def load_models():
    # Load the speaker recognition model
    sr_model = SpeakerRecognition.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")

    # Load the encoder classifier model
    ec_model = EncoderClassifier.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")

    p_model = Pretrained.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")
    return sr_model, ec_model, p_model

def extract_embeddings(p_model, reference_file):
    # Extract the embeddings of the reference audio file
    waveform_x = p_model.load_audio(path=reference_file)
    batch_x = waveform_x.unsqueeze(0)
    emb_ref = ec_model.encode_batch(batch_x, normalize=True)
    return emb_ref

def compare_embeddings(emb_ref, emb_y):
    similarity = torch.nn.CosineSimilarity(dim=-1, eps=1e-6)
    score = similarity(emb_y, emb_ref)
    is_speaker = 1 if score > 0.25 else 0
    return is_speaker

def create_metadata_table(metadata_db_path):
    # Connect to the SQLite database
    conn = sqlite3.connect(metadata_db_path)
    c = conn.cursor()

    # Create the table for storing metadata
    c.execute('''CREATE TABLE IF NOT EXISTS speaker_files
                 (id INTEGER PRIMARY KEY AUTOINCREMENT, file_path TEXT, is_speaker INTEGER)''')
    return conn, c

def check_similarity(folder_path, metadata_db_path, temp_dir, emb_ref, p_model, ec_model):
    count_fail = 0
    # Loop through all the files in the folder and check for similarity with reference audio file
    for file in natsorted(os.listdir(folder_path), key=lambda x: (x.split("_")[0], int(x.split("_")[1].split(".")[0][7:]))):
        if file.endswith('.wav'):
            waveform_y = p_model.load_audio(path=os.path.join(folder_path, file), savedir=temp_dir)
            batch_y = waveform_y.unsqueeze(0)
            emb_y = ec_model.encode_batch(batch_y, normalize=True)
            is_speaker = compare_embeddings(emb_ref, emb_y)
            if is_speaker == 0:
                count_fail += 1
            print(f"File: {file} Passes Verification: {is_speaker}")
            
            # Insert the metadata into the database
            c.execute("INSERT INTO speaker_files (file_path, is_speaker) VALUES (?, ?)", (os.path.join(folder_path, file), is_speaker))
            
            os.remove(os.path.join(temp_dir, file))

# %%
# Load the models
sr_model, ec_model, p_model = load_models()

# Extract the embeddings of the reference audio file
reference_file = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/data/training/standard.wav"
emb_ref = extract_embeddings(p_model, reference_file)

# %%
# Create the metadata table
metadata_db_path = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/metadata.db"
conn, c = create_metadata_table(metadata_db_path)

# %%
# Check for similarity
folder_path = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data"
temp_dir = tempfile.gettempdir()
check_similarity(folder_path, metadata_db_path, temp_dir, emb_ref, p_model, ec_model)
# Out:
# File: video1_segment1.wav Passes Verification: 1
# File: video1_segment2.wav Passes Verification: 1
# File: video1_segment3.wav Passes Verification: 1
# File: video1_segment4.wav Passes Verification: 1
# File: video1_segment5.wav Passes Verification: 1
# File: video1_segment6.wav Passes Verification: 1
# File: video1_segment7.wav Passes Verification: 1
# File: video1_segment8.wav Passes Verification: 1
# File: video1_segment9.wav Passes Verification: 1
# File: video1_segment10.wav Passes Verification: 1
# File: video1_segment11.wav Passes Verification: 1
# File: video1_segment12.wav Passes Verification: 1
# File: video1_segment13.wav Passes Verification: 1
# File: video1_segment14.wav Passes Verification: 1
# File: video1_segment15.wav Passes Verification: 1
# File: video1_segment16.wav Passes Verification: 1
# File: video1_segment17.wav Passes Verification: 1
# File: video1_segment18.wav Passes Verification: 1
# File: video1_segment19.wav Passes Verification: 1
# File: video1_segment20.wav Passes Verification: 1
# File: video1_segment21.wav Passes Verification: 1
# File: video1_segment22.wav Passes Verification: 1
# File: video1_segment23.wav Passes Verification: 1
# File: video1_segment24.wav Passes Verification: 1
# File: video1_segment25.wav Passes Verification: 1
# File: video1_segment26.wav Passes Verification: 1
# File: video1_segment27.wav Passes Verification: 1
# File: video1_segment28.wav Passes Verification: 1
# File: video1_segment29.wav Passes Verification: 1
# File: video1_segment30.wav Passes Verification: 1
# File: video1_segment31.wav Passes Verification: 1
# File: video1_segment32.wav Passes Verification: 1
# File: video1_segment33.wav Passes Verification: 1
# File: video1_segment34.wav Passes Verification: 1
# File: video1_segment35.wav Passes Verification: 1
# File: video1_segment36.wav Passes Verification: 1
# File: video1_segment37.wav Passes Verification: 1
# File: video2_segment144.wav Passes Verification: 0
# File: video2_segment145.wav Passes Verification: 1
# File: video2_segment146.wav Passes Verification: 0
# File: video2_segment147.wav Passes Verification: 0
# File: video2_segment148.wav Passes Verification: 0
# File: video2_segment149.wav Passes Verification: 1
# File: video2_segment150.wav Passes Verification: 1
# File: video2_segment151.wav Passes Verification: 0
# File: video2_segment152.wav Passes Verification: 1
# File: video2_segment153.wav Passes Verification: 0
# File: video2_segment154.wav Passes Verification: 1
# File: video2_segment155.wav Passes Verification: 1
# File: video2_segment156.wav Passes Verification: 0
# File: video2_segment157.wav Passes Verification: 0
# File: video2_segment158.wav Passes Verification: 0
# File: video2_segment159.wav Passes Verification: 1
# File: video2_segment160.wav Passes Verification: 0
# File: video2_segment161.wav Passes Verification: 0
# File: video2_segment162.wav Passes Verification: 1
# File: video2_segment163.wav Passes Verification: 1
# File: video2_segment164.wav Passes Verification: 1
# File: video2_segment165.wav Passes Verification: 1

# %%
# Commit the changes to the database and close the connection
conn.commit()
conn.close()

# %%
import sqlite3

metadata_db_path = "metadata.db"

# Connect to the SQLite database
conn = sqlite3.connect(metadata_db_path)
c = conn.cursor()

# Query the database and print the results
for row in c.execute("SELECT * FROM speaker_files"):
    print(row)

# Close the connection
conn.close()
# Out:
# (1, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment1.wav', 1)
# (2, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment2.wav', 1)
# (3, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment3.wav', 1)
# (4, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment4.wav', 1)
# (5, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment5.wav', 1)
# (6, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment6.wav', 1)
# (7, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment7.wav', 1)
# (8, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment8.wav', 1)
# (9, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment9.wav', 1)
# (10, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment10.wav', 1)
# (11, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment11.wav', 1)
# (12, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment12.wav', 1)
# (13, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment13.wav', 1)
# (14, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment14.wav', 1)
# (15, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment15.wav', 1)
# (16, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment16.wav', 1)
# (17, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment17.wav', 1)
# (18, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment18.wav', 1)
# (19, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment19.wav', 1)
# (20, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment20.wav', 1)
# (21, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment21.wav', 1)
# (22, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment22.wav', 1)
# (23, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment23.wav', 1)
# (24, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment24.wav', 1)
# (25, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment25.wav', 1)
# (26, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment26.wav', 1)
# (27, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment27.wav', 1)
# (28, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment28.wav', 1)
# (29, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment29.wav', 1)
# (30, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment30.wav', 1)
# (31, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment31.wav', 1)
# (32, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment32.wav', 1)
# (33, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment33.wav', 1)
# (34, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment34.wav', 1)
# (35, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment35.wav', 1)
# (36, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment36.wav', 1)
# (37, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment37.wav', 1)
# (38, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment38.wav', 1)
# (39, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment39.wav', 1)
# (40, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment40.wav', 1)
# (41, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment41.wav', 1)
# (42, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment42.wav', 1)
# (43, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment43.wav', 1)
# (44, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment44.wav', 1)
# (45, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment45.wav', 1)
# (46, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment46.wav', 1)
# (47, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment47.wav', 1)
# (48, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment48.wav', 1)
# (49, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment49.wav', 1)
# (50, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment50.wav', 1)
# (51, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment51.wav', 1)
# (52, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment52.wav', 1)
# (53, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment53.wav', 1)
# (54, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment54.wav', 1)
# (55, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment55.wav', 1)
# (56, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment56.wav', 1)
# (57, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment57.wav', 1)
# (58, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment58.wav', 1)
# (59, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment59.wav', 1)
# (60, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_segment60.wav', 1)
# (61, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video1_seg
'/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment59.wav', 1)
# (164, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment60.wav', 1)
# (165, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment61.wav', 0)
# (166, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment62.wav', 0)
# (167, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment63.wav', 1)
# (168, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment64.wav', 0)
# (169, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment65.wav', 1)
# (170, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment66.wav', 1)
# (171, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment67.wav', 0)
# (172, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment68.wav', 0)
# (173, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment69.wav', 1)
# (174, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment70.wav', 1)
# (175, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment71.wav', 1)
# (176, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment72.wav', 1)
# (177, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment73.wav', 0)
# (178, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment74.wav', 0)
# (179, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment75.wav', 1)
# (180, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment76.wav', 0)
# (181, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment77.wav', 1)
# (182, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment78.wav', 1)
# (183, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment79.wav', 1)
# (184, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment80.wav', 0)
# (185, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment81.wav', 1)
# (186, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment82.wav', 1)
# (187, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment83.wav', 1)
# (188, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment84.wav', 1)
# (189, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment85.wav', 0)
# (190, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment86.wav', 1)
# (191, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment87.wav', 0)
# (192, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment88.wav', 0)
# (193, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment89.wav', 1)
# (194, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment90.wav', 0)
# (195, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment91.wav', 0)
# (196, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment92.wav', 1)
# (197, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment93.wav', 0)
# (198, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment94.wav', 0)
# (199, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment95.wav', 0)
# (200, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment96.wav', 0)
# (201, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment97.wav', 1)
# (202, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment98.wav', 0)
# (203, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment99.wav', 1)
# (204, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment100.wav', 0)
# (205, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment101.wav', 1)
# (206, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment102.wav', 1)
# (207, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment103.wav', 1)
# (208, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment104.wav', 1)
# (209, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment105.wav', 1)
# (210, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment106.wav', 1)
# (211, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment107.wav', 1)
# (212, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment108.wav', 0)
# (213, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment109.wav', 0)
# (214, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment110.wav', 0)
# (215, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment111.wav', 0)
# (216, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment112.wav', 1)
# (217, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment113.wav', 0)
# (218, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment114.wav', 0)
# (219, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment115.wav', 0)
# (220, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment116.wav', 1)
# (221, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment117.wav', 1)
# (222, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment118.wav', 1)
# (223, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment119.wav', 0)
# (224, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment120.wav', 1)
# (225, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment121.wav', 1)
# (226, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment122.wav', 1)
# (227, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment123.wav', 0)
# (228, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment124.wav', 1)
# (229, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment125.wav', 1)
# (230, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment126.wav', 0)
# (231, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment127.wav', 1)
# (232, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment128.wav', 1)
# (233, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment129.wav', 1)
# (234, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment130.wav', 0)
# (235, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment131.wav', 0)
# (236, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment132.wav', 1)
# (237, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment133.wav', 1)
# (238, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment134.wav', 1)
# (239, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment135.wav', 1)
# (240, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment136.wav', 1)
# (241, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment137.wav', 1)
# (242, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment138.wav', 0)
# (243, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment139.wav', 0)
# (244, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment140.wav', 1)
# (245, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment141.wav', 1)
# (246, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment142.wav', 1)
# (247, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment143.wav', 1)
# (248, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment144.wav', 0)
# (249, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment145.wav', 1)
# (250, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment146.wav', 0)
# (251, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment147.wav', 0)
# (252, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment148.wav', 0)
# (253, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment149.wav', 1)
# (254, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment150.wav', 1)
# (255, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment151.wav', 0)
# (256, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment152.wav', 1)
# (257, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment153.wav', 0)
# (258, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment154.wav', 1)
# (259, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment155.wav', 1)
# (260, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment156.wav', 0)
# (261, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment157.wav', 0)
# (262, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment158.wav', 0)
# (263, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment159.wav', 1)
# (264, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment160.wav', 0)
# (265, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment161.wav', 0)
# (266, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment162.wav', 1)
# (267, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment163.wav', 1)
# (268, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment164.wav', 1)
# (269, '/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data/video2_segment165.wav', 1)

# %%
import os
import torch
from speechbrain.pretrained import SpeakerRecognition
from speechbrain.pretrained import EncoderClassifier
from speechbrain.pretrained import Pretrained
import sqlite3
import tempfile
import re
from natsort import natsorted

def load_models():
    # Load the speaker recognition model
    sr_model = SpeakerRecognition.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")

    # Load the encoder classifier model
    ec_model = EncoderClassifier.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")

    p_model = Pretrained.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")
    return sr_model, ec_model, p_model

def extract_embeddings(p_model, ec_model, reference_file):
    # Extract the embeddings of the reference audio file
    waveform_x = p_model.load_audio(path=reference_file)
    batch_x = waveform_x.unsqueeze(0)
    emb_ref = ec_model.encode_batch(batch_x, normalize=True)
    return emb_ref

def compare_embeddings(emb_ref, emb_y):
    similarity = torch.nn.CosineSimilarity(dim=-1, eps=1e-6)
    score = similarity(emb_y, emb_ref)
    is_speaker = 1 if score > 0.25 else 0
    return is_speaker

def create_metadata_table(metadata_db_path):
    # Connect to the SQLite database
    conn = sqlite3.connect(metadata_db_path)
    c = conn.cursor()

    # Create the table for storing metadata
    c.execute('''CREATE TABLE IF NOT EXISTS speaker_files
                 (id INTEGER PRIMARY KEY AUTOINCREMENT, file_path TEXT, is_speaker INTEGER)''')
    return conn, c

def check_similarity(folder_path, c, temp_dir, emb_ref, p_model, ec_model):
    count_fail = 0
    # Loop through all the files in the folder and check for similarity with reference audio file
    for file in natsorted(os.listdir(folder_path), key=lambda x: (x.split("_")[0], int(x.split("_")[1].split(".")[0][7:]))):
        if file.endswith('.wav'):
            waveform_y = p_model.load_audio(path=os.path.join(folder_path, file), savedir=temp_dir)
            batch_y = waveform_y.unsqueeze(0)
            emb_y = ec_model.encode_batch(batch_y, normalize=True)
            is_speaker = compare_embeddings(emb_ref, emb_y)
            if is_speaker == 0:
                count_fail += 1
            print(f"File: {file} Passes Verification: {is_speaker}")
            
            # Insert the metadata into the database
            c.execute("INSERT INTO speaker_files (file_path, is_speaker) VALUES (?, ?)", (os.path.join(folder_path, file), is_speaker))
            
            os.remove(os.path.join(temp_dir, file))


# Usage

# # Load the models
# sr_model, ec_model, p_model = load_models()

# # Extract the embeddings of the reference audio file
# reference_file = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/data/training/standard.wav"
# emb_ref = extract_embeddings(p_model, ec_model, reference_file)

# # Create the metadata table
# metadata_db_path = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/metadata.db"
# conn, c = create_metadata_table(metadata_db_path)

# # Check for similarity
# folder_path = "/Users/harshbhatia/Documents/CBD/Charlie_CBD/nexusbot/tests/segment_data"
# temp_dir = tempfile.gettempdir()
# check_similarity(folder_path, c, temp_dir, emb_ref, p_model, ec_model)

# # Commit the changes to the database and close the connection
# conn.commit()
# conn.close()
